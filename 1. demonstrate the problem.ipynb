# %% [markdown]
# # full segments modelling

# %% [markdown]
# # split income_type and build model for each group to achive higher metric

# %% [markdown]
# -> better metric

# %% [markdown]
# # mistake happens: OOT metrics drop

# %% [markdown]
# # explain about smaller sample → less variance → inflated AUC
