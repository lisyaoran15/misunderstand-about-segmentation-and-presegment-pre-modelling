# %% [markdown]
# # test statistical justification: Chow test / interaction test

# %% [markdown]
# # fundamentally different populations

# %% [markdown]
# # Ví dụ đúng: salaried vs self-employed (data source khác)

# %% [markdown]
# # Ví dụ sai: age group 25-35 vs 36-45 (continuum, không khác về data)
